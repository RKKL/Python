# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('KSI_Scales_0417.csv')

# %%
df
# Out:
#          Index_      ACCNUM  YEAR        DATE  TIME  HOUR  \
# 0       3389067      893184  2006  2006-01-01   236     2
# 1       3389068      893184  2006  2006-01-01   236     2
# 2       3389069      893184  2006  2006-01-01   236     2
# 3       3389070      893184  2006  2006-01-01   236     2
# 4       3389071      893184  2006  2006-01-01   236     2
# ...         ...         ...   ...         ...   ...   ...
# 16088  81356467  9002496688  2019  2019-12-27  2324    23
# 16089  81356468  9002496688  2019  2019-12-27  2324    23
# 16090  81340413  9002500260  2019  2019-12-28  1514    15
# 16091  81340414  9002500260  2019  2019-12-28  1514    15
# 16092  81340415  9002500260  2019  2019-12-28  1514    15
#
#                     District  WardNum  Division      ROAD_CLASS  ...  \
# 0      Toronto and East York     19.0        54  Major Arterial  ...
# 1      Toronto and East York     19.0        54  Major Arterial  ...
# 2      Toronto and East York     19.0        54  Major Arterial  ...
# 3      Toronto and East York     19.0        54  Major Arterial  ...
# 4      Toronto and East York     19.0        54  Major Arterial  ...
# ...                      ...      ...       ...             ...  ...
# 16088         Etobicoke York      7.0        31  Major Arterial  ...
# 16089         Etobicoke York      7.0        31  Major Arterial  ...
# 16090  Toronto and East York     11.0        52  Major Arterial  ...
# 16091  Toronto and East York     11.0        52  Major Arterial  ...
# 16092  Toronto and East York     11.0        52  Major Arterial  ...
#
#                          DRIVACT     DRIVCOND  DRIVCOND_Scale SPEEDING  \
# 0                            NaN          NaN             NaN      Yes
# 1                            NaN          NaN             NaN      Yes
# 2               Driving Properly       Normal             0.0      Yes
# 3                            NaN          NaN             NaN      Yes
# 4                            NaN          NaN             NaN      Yes
# ...                          ...          ...             ...      ...
# 16088           Driving Properly       Normal             0.0      NaN
# 16089                        NaN          NaN             NaN      NaN
# 16090  Disobeyed Traffic Control  Inattentive             5.0      NaN
# 16091           Driving Properly       Normal             0.0      NaN
# 16092                        NaN          NaN             NaN      NaN
#
#        ALCOHOL Hood_ID                Neighbourhood ObjectId  Vulnerability  \
# 0          Yes      60        Woodbine-Lumsden (60)        1            2.0
# 1          Yes      60        Woodbine-Lumsden (60)        2            2.0
# 2          Yes      60        Woodbine-Lumsden (60)        3            2.0
# 3          Yes      60        Woodbine-Lumsden (60)        4            2.0
# 4          Yes      60        Woodbine-Lumsden (60)        5            2.0
# ...        ...     ...                          ...      ...            ...
# 16088      NaN      25  Glenfield-Jane Heights (25)    16089            2.0
# 16089      NaN      25  Glenfield-Jane Heights (25)    16090            7.0
# 16090      NaN      76     Bay Street Corridor (76)    16091            2.0
# 16091      NaN      76     Bay Street Corridor (76)    16092            2.0
# 16092      NaN      76     Bay Street Corridor (76)    16093            7.0
#
#       Vehicle mass
# 0              NaN
# 1              NaN
# 2              6.0
# 3              NaN
# 4              NaN
# ...            ...
# 16088          6.0
# 16089          NaN
# 16090          6.0
# 16091          6.0
# 16092          NaN
#
# [16093 rows x 41 columns]

# %%
new_df = df[df.columns.drop(list(df.filter(regex='Unnamed:')))]
new_df
# Out:
#          Index_      ACCNUM  YEAR        DATE  TIME  HOUR  \
# 0       3389067      893184  2006  2006-01-01   236     2
# 1       3389068      893184  2006  2006-01-01   236     2
# 2       3389069      893184  2006  2006-01-01   236     2
# 3       3389070      893184  2006  2006-01-01   236     2
# 4       3389071      893184  2006  2006-01-01   236     2
# ...         ...         ...   ...         ...   ...   ...
# 16088  81356467  9002496688  2019  2019-12-27  2324    23
# 16089  81356468  9002496688  2019  2019-12-27  2324    23
# 16090  81340413  9002500260  2019  2019-12-28  1514    15
# 16091  81340414  9002500260  2019  2019-12-28  1514    15
# 16092  81340415  9002500260  2019  2019-12-28  1514    15
#
#                     District  WardNum  Division      ROAD_CLASS  ...  \
# 0      Toronto and East York     19.0        54  Major Arterial  ...
# 1      Toronto and East York     19.0        54  Major Arterial  ...
# 2      Toronto and East York     19.0        54  Major Arterial  ...
# 3      Toronto and East York     19.0        54  Major Arterial  ...
# 4      Toronto and East York     19.0        54  Major Arterial  ...
# ...                      ...      ...       ...             ...  ...
# 16088         Etobicoke York      7.0        31  Major Arterial  ...
# 16089         Etobicoke York      7.0        31  Major Arterial  ...
# 16090  Toronto and East York     11.0        52  Major Arterial  ...
# 16091  Toronto and East York     11.0        52  Major Arterial  ...
# 16092  Toronto and East York     11.0        52  Major Arterial  ...
#
#                          DRIVACT     DRIVCOND  DRIVCOND_Scale SPEEDING  \
# 0                            NaN          NaN             NaN      Yes
# 1                            NaN          NaN             NaN      Yes
# 2               Driving Properly       Normal             0.0      Yes
# 3                            NaN          NaN             NaN      Yes
# 4                            NaN          NaN             NaN      Yes
# ...                          ...          ...             ...      ...
# 16088           Driving Properly       Normal             0.0      NaN
# 16089                        NaN          NaN             NaN      NaN
# 16090  Disobeyed Traffic Control  Inattentive             5.0      NaN
# 16091           Driving Properly       Normal             0.0      NaN
# 16092                        NaN          NaN             NaN      NaN
#
#        ALCOHOL Hood_ID                Neighbourhood ObjectId  Vulnerability  \
# 0          Yes      60        Woodbine-Lumsden (60)        1            2.0
# 1          Yes      60        Woodbine-Lumsden (60)        2            2.0
# 2          Yes      60        Woodbine-Lumsden (60)        3            2.0
# 3          Yes      60        Woodbine-Lumsden (60)        4            2.0
# 4          Yes      60        Woodbine-Lumsden (60)        5            2.0
# ...        ...     ...                          ...      ...            ...
# 16088      NaN      25  Glenfield-Jane Heights (25)    16089            2.0
# 16089      NaN      25  Glenfield-Jane Heights (25)    16090            7.0
# 16090      NaN      76     Bay Street Corridor (76)    16091            2.0
# 16091      NaN      76     Bay Street Corridor (76)    16092            2.0
# 16092      NaN      76     Bay Street Corridor (76)    16093            7.0
#
#       Vehicle mass
# 0              NaN
# 1              NaN
# 2              6.0
# 3              NaN
# 4              NaN
# ...            ...
# 16088          6.0
# 16089          NaN
# 16090          6.0
# 16091          6.0
# 16092          NaN
#
# [16093 rows x 41 columns]

.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16093 entries, 0 to 16092
# Data columns (total 41 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Index_            16093 non-null  int64
#  1   ACCNUM            16093 non-null  int64
#  2   YEAR              16093 non-null  int64
#  3   DATE              16093 non-null  object
#  4   TIME              16093 non-null  int64
#  5   HOUR              16093 non-null  int64
#  6   District          16080 non-null  object
#  7   WardNum           13795 non-null  float64
#  8   Division          16093 non-null  int64
#  9   ROAD_CLASS        15725 non-null  object
#  10  ROAD_CLASS_Scale  15679 non-null  float64
#  11  TRAFFCTL          16064 non-null  object
#  12  TRAFFCTL_Scale    16064 non-null  float64
#  13  VISIBILITY        16071 non-null  object
#  14  VISIBILITY_Scale  16071 non-null  float64
#  15  LIGHT             16093 non-null  object
#  16  LIGHT_Scale       16087 non-null  float64
#  17  RDSFCOND          16093 non-null  object
#  18  RDSFCOND_Scale    15919 non-null  float64
#  19  ACCLASS           16093 non-null  object
#  20  IMPACTYPE         16089 non-null  object
#  21  INVTYPE           16083 non-null  object
#  22  INVTYPE_Scale     16083 non-null  float64
#  23  INVAGE            16093 non-null  object
#  24  INVAGE_Scale      13552 non-null  float64
#  25  INJURY            14484 non-null  object
#  26  INJURY_Scale      14484 non-null  float64
#  27  INITDIR           11257 non-null  object
#  28  VEHTYPE           13566 non-null  object
#  29  VEHTYPE_Scale     13566 non-null  float64
#  30  MANOEUVER         9141 non-null   object
#  31  DRIVACT           8032 non-null   object
#  32  DRIVCOND          8032 non-null   object
#  33  DRIVCOND_Scale    8032 non-null   float64
#  34  SPEEDING          2157 non-null   object
#  35  ALCOHOL           713 non-null    object
#  36  Hood_ID           16093 non-null  int64
#  37  Neighbourhood     16093 non-null  object
#  38  ObjectId          16093 non-null  int64
#  39  Vulnerability     16083 non-null  float64
#  40  Vehicle mass      13566 non-null  float64
# dtypes: float64(13), int64(8), object(20)
# memory usage: 5.0+ MB

# %% [markdown]
# ## <u>Quick Looks</u>
#
# Variables to highlight in dataset for prediction:
#
#     ROAD_CLASS
#     WardNum
#     Division
#     TRAFFCTRL
#     VISIBILITY
#     LIGHT
#     RDSFCOND
#     INVTYPE
#     INVAGE
#     INJURY
#     VEHTYPE
#     DRIVCOND

# %% [markdown]
# ### Road_Class

# %%
countplt, ax = plt.subplots(figsize = (8,4))
ax =sb.countplot(x = 'ROAD_CLASS', data=new_df, ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

plt.show()

# %% [markdown]
# ### WardNum

# %%
countplt, ax = plt.subplots(figsize = (16,4))
ax =sb.countplot(x = 'WardNum', data=new_df)

plt.show()

# %% [markdown]
# ### Division

# %%
countplt, ax = plt.subplots(figsize = (8,4))
ax =sb.countplot(x = 'Division', data=new_df)

plt.show()

# %% [markdown]
# ### TRAFFCTL

# %%
countplt, ax = plt.subplots(figsize = (8,4))
ax =sb.countplot(x = 'TRAFFCTL', data=new_df, ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

plt.show()

# %% [markdown]
# ### VISIBILITY

# %%
countplt, ax = plt.subplots(figsize = (8,4))
ax =sb.countplot(x = 'VISIBILITY', data=new_df, ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

plt.show()

# %% [markdown]
# <font color = "red">Suggest to bin results together as such:
#
#     Clear
#     Rain = Rain, Freezing Rain
#     Snow = Snow, Drifting Snow
#     Other = Other, "Fog, Mist, Smoke, Dust", Strong wind

# %% [markdown]
# ### LIGHT

# %%
countplt, ax = plt.subplots(figsize = (8,4))
ax =sb.countplot(x = 'LIGHT', data=new_df, ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

plt.show()

# %% [markdown]
# ### RDSFCOND

# %%
countplt, ax = plt.subplots(figsize = (8,4))
ax =sb.countplot(x = 'RDSFCOND', data=new_df, ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

plt.show()

# %% [markdown]
# ### INVTYPE

# %%
countplt, ax = plt.subplots(figsize = (8,4))
ax =sb.countplot(x = 'INVTYPE', data=new_df, ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

plt.show()

# %% [markdown]
# <font color = "red">Suggest to bin different results together as such:
#
#     Pedestrian = Pedestrian, In-Line Skater, Pedestrian - Not Hit
#     Passenger
#     Other = Other, Wheelchair, Other Property Owner, Witness, Trailer Owner
#     Cyclist = Cyclist, Cyclist Passenger
#     Vehicle Owner
#     Driver = Driver, Driver - Not Hit, Truck Driver
#     Motorcyle Occupants = Motorcycle Passenger, Motorcyle Driver, Moped Driver

# %% [markdown]
# ### INVAGE

# %%
df.sort_values(by=['INVAGE'], inplace=True)

# %%
countplt, ax = plt.subplots(figsize = (16,4))
ax =sb.countplot(x = 'INVAGE', data=new_df, ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

plt.show()

# %% [markdown]
# ### INJURY

# %%
countplt, ax = plt.subplots(figsize = (8,4))
ax =sb.countplot(x = 'INJURY', data=new_df)

plt.show()

# %% [markdown]
# ### VEHTYPE

# %%
countplt, ax = plt.subplots(figsize = (8,4))
ax =sb.countplot(x = 'VEHTYPE', data=new_df, ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

plt.show()

# %% [markdown]
# ### DRIVCOND

# %%
countplt, ax = plt.subplots(figsize = (8,4))
ax =sb.countplot(x = 'DRIVCOND', data=new_df, ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

plt.show()

# %% [markdown]
# ## <u>Correlations</u>

# %%
corrdf = new_df.corr()

corrdf
# Out:
#                     Index_    ACCNUM      YEAR      TIME      HOUR   WardNum  \
# Index_            1.000000  0.946346  0.861860  0.026144  0.030105  0.011783
# ACCNUM            0.946346  1.000000  0.881602  0.021347  0.024178  0.018460
# YEAR              0.861860  0.881602  1.000000  0.018423  0.020746  0.023025
# TIME              0.026144  0.021347  0.018423  1.000000  0.994090  0.013894
# HOUR              0.030105  0.024178  0.020746  0.994090  1.000000  0.015667
# WardNum           0.011783  0.018460  0.023025  0.013894  0.015667  1.000000
# Division         -0.008520 -0.007740  0.002230  0.027399  0.026882  0.588603
# ROAD_CLASS_Scale  0.020830  0.023829  0.023985 -0.007449 -0.005886 -0.057896
# TRAFFCTL_Scale    0.015318  0.021639  0.020230 -0.001875 -0.003886  0.033263
# VISIBILITY_Scale -0.049191 -0.044205 -0.050713 -0.001717  0.001296  0.012119
# LIGHT_Scale      -0.053298 -0.050778 -0.091784  0.030993  0.053638 -0.015241
# RDSFCOND_Scale   -0.042033 -0.035962 -0.048280 -0.037062 -0.034526  0.019861
# INVTYPE_Scale     0.074012  0.070561  0.080240  0.057341  0.056110  0.007160
# INVAGE_Scale      0.007573  0.006576  0.028556  0.028328  0.021735  0.017437
# INJURY_Scale     -0.006361 -0.012120  0.005251 -0.034679 -0.034904  0.000538
# VEHTYPE_Scale     0.376188  0.359931  0.324460  0.002961  0.001991 -0.009517
# DRIVCOND_Scale    0.031220  0.023400  0.035589 -0.069116 -0.067884  0.020943
# Hood_ID          -0.001706  0.003906  0.019537 -0.013828 -0.014688  0.712596
# ObjectId          0.841724  0.847290  0.990150  0.019927  0.022033  0.023557
# Vulnerability     0.074012  0.070561  0.080240  0.057341  0.056110  0.007160
# Vehicle mass      0.376188  0.359931  0.324460  0.002961  0.001991 -0.009517
#
#                   Division  ROAD_CLASS_Scale  TRAFFCTL_Scale  \
# Index_           -0.008520          0.020830        0.015318
# ACCNUM           -0.007740          0.023829        0.021639
# YEAR              0.002230          0.023985        0.020230
# TIME              0.027399         -0.007449       -0.001875
# HOUR              0.026882         -0.005886       -0.003886
# WardNum           0.588603         -0.057896        0.033263
# Division          1.000000         -0.013036        0.025733
# ROAD_CLASS_Scale -0.013036          1.000000        0.210023
# TRAFFCTL_Scale    0.025733          0.210023        1.000000
# VISIBILITY_Scale -0.011329          0.030098       -0.008998
# LIGHT_Scale      -0.009056          0.037719       -0.051862
# RDSFCOND_Scale    0.009235          0.023309       -0.017359
# INVTYPE_Scale     0.017116         -0.025029        0.012472
# INVAGE_Scale     -0.010014          0.016102        0.031782
# INJURY_Scale     -0.001920         -0.017136       -0.025030
# VEHTYPE_Scale    -0.021703          0.045040        0.025520
# DRIVCOND_Scale    0.030210         -0.047641        0.000055
# Hood_ID           0.260947         -0.042682        0.002993
# ObjectId          0.005115          0.026346        0.019869
# Vulnerability     0.017116         -0.025029        0.012472
# Vehicle mass     -0.021703          0.045040        0.025520
#
#                   VISIBILITY_Scale  ...  RDSFCOND_Scale  INVTYPE_Scale  \
# Index_                   -0.049191  ...       -0.042033       0.074012
# ACCNUM                   -0.044205  ...       -0.035962       0.070561
# YEAR                     -0.050713  ...       -0.048280       0.080240
# TIME                     -0.001717  ...       -0.037062       0.057341
# HOUR                      0.001296  ...       -0.034526       0.056110
# WardNum                   0.012119  ...        0.019861       0.007160
# Division                 -0.011329  ...        0.009235       0.017116
# ROAD_CLASS_Scale          0.030098  ...        0.023309      -0.025029
# TRAFFCTL_Scale           -0.008998  ...       -0.017359       0.012472
# VISIBILITY_Scale          1.000000  ...        0.740694       0.014100
# LIGHT_Scale               0.170198  ...        0.169934      -0.013302
# RDSFCOND_Scale            0.740694  ...        1.000000      -0.016341
# INVTYPE_Scale             0.014100  ...       -0.016341       1.000000
# INVAGE_Scale             -0.006025  ...       -0.000524       0.099638
# INJURY_Scale              0.004881  ...        0.009396       0.618646
# VEHTYPE_Scale            -0.011306  ...        0.006554      -0.473492
# DRIVCOND_Scale           -0.000507  ...       -0.014191      -0.045405
# Hood_ID                   0.012814  ...        0.001808       0.031709
# ObjectId                 -0.044921  ...       -0.049302       0.082811
# Vulnerability             0.014100  ...       -0.016341       1.000000
# Vehicle mass             -0.011306  ...        0.006554      -0.473492
#
#                   INVAGE_Scale  INJURY_Scale  VEHTYPE_Scale  DRIVCOND_Scale  \
# Index_                0.007573     -0.006361       0.376188        0.031220
# ACCNUM                0.006576     -0.012120       0.359931        0.023400
# YEAR                  0.028556      0.005251       0.324460        0.035589
# TIME                  0.028328     -0.034679       0.002961       -0.069116
# HOUR                  0.021735     -0.034904       0.001991       -0.067884
# WardNum               0.017437      0.000538      -0.009517        0.020943
# Division             -0.010014     -0.001920      -0.021703        0.030210
# ROAD_CLASS_Scale      0.016102     -0.017136       0.045040       -0.047641
# TRAFFCTL_Scale        0.031782     -0.025030       0.025520        0.000055
# VISIBILITY_Scale     -0.006025      0.004881      -0.011306       -0.000507
# LIGHT_Scale          -0.138896      0.021819      -0.054291        0.081685
# RDSFCOND_Scale       -0.000524      0.009396       0.006554       -0.014191
# INVTYPE_Scale         0.099638      0.618646      -0.473492       -0.045405
# INVAGE_Scale          1.000000      0.078703       0.089958       -0.041525
# INJURY_Scale          0.078703      1.000000      -0.485048        0.016298
# VEHTYPE_Scale         0.089958     -0.485048       1.000000        0.009534
# DRIVCOND_Scale       -0.041525      0.016298       0.009534        1.000000
# Hood_ID               0.004490     -0.002786      -0.015566        0.005619
# ObjectId              0.033040      0.007487       0.315944        0.036926
# Vulnerability         0.099638      0.618646      -0.473492       -0.045405
# Vehicle mass          0.089958     -0.485048       1.000000        0.009534
#
#                    Hood_ID  ObjectId  Vulnerability  Vehicle mass
# Index_           -0.001706  0.841724       0.074012      0.376188
# ACCNUM            0.003906  0.847290       0.070561      0.359931
# YEAR              0.019537  0.990150       0.080240      0.324460
# TIME             -0.013828  0.019927       0.057341      0.002961
# HOUR             -0.014688  0.022033       0.056110      0.001991
# WardNum           0.712596  0.023557       0.007160     -0.009517
# Division          0.260947  0.005115       0.017116     -0.021703
# ROAD_CLASS_Scale -0.042682  0.026346      -0.025029      0.045040
# TRAFFCTL_Scale    0.002993  0.019869       0.012472      0.025520
# VISIBILITY_Scale  0.012814 -0.044921       0.014100     -0.011306
# LIGHT_Scale      -0.013766 -0.087650      -0.013302     -0.054291
# RDSFCOND_Scale    0.001808 -0.049302      -0.016341      0.006554
# INVTYPE_Scale     0.031709  0.082811       1.000000     -0.473492
# INVAGE_Scale      0.004490  0.033040       0.099638      0.089958
# INJURY_Scale     -0.002786  0.007487       0.618646     -0.485048
# VEHTYPE_Scale    -0.015566  0.315944      -0.473492      1.000000
# DRIVCOND_Scale    0.005619  0.036926      -0.045405      0.009534
# Hood_ID           1.000000  0.021865       0.031709     -0.015566
# ObjectId          0.021865  1.000000       0.082811      0.315944
# Vulnerability     0.031709  0.082811       1.000000     -0.473492
# Vehicle mass     -0.015566  0.315944      -0.473492      1.000000
#
# [21 rows x 21 columns]

# %%
corrmat = new_df.corr()
highest_corr_vars = corrmat.index
plt.figure(figsize=(20,10))
g = sb.heatmap(new_df[highest_corr_vars].corr(),annot = True,cmap = "RdYlGn")

# %% [markdown]
# ## <u>Missing Values</u>
#
# Variables to highlight in dataset for prediction:
#
#     ROAD_CLASS
#     WardNum
#     Division
#     TRAFFCTL
#     VISIBILITY
#     LIGHT
#     RDSFCOND
#     INVTYPE
#     INVAGE
#     INJURY
#     VEHTYPE
#     DRIVCOND

# %%
new_df.ROAD_CLASS.value_counts(dropna=False)
# Out:
# Major Arterial         11555
# Minor Arterial          2462
# Collector                900
# Local                    727
# NaN                      368
# Other                     33
# Expressway                24
# Pending                   13
# Laneway                   10
# Major Arterial Ramp        1
# Name: ROAD_CLASS, dtype: int64

# %%
new_df.WardNum.value_counts(dropna=False)
# Out:
# NaN     2298
# 10.0     930
# 1.0      867
# 3.0      740
# 11.0     738
# 5.0      719
# 14.0     712
# 4.0      639
# 21.0     630
# 13.0     618
# 9.0      607
# 22.0     563
# 23.0     558
# 6.0      544
# 7.0      505
# 20.0     486
# 18.0     459
# 24.0     438
# 2.0      437
# 25.0     423
# 8.0      421
# 19.0     409
# 17.0     388
# 16.0     373
# 12.0     347
# 15.0     244
# Name: WardNum, dtype: int64

# %%
new_df.Division.value_counts(dropna=False)
# Out:
# 42    1612
# 32    1237
# 41    1218
# 23    1200
# 14    1088
# 22    1020
# 43    1004
# 53     902
# 31     853
# 52     852
# 51     845
# 33     839
# 12     807
# 54     706
# 11     670
# 13     659
# 55     581
# Name: Division, dtype: int64

# %%
new_df.TRAFFCTL.value_counts(dropna=False)
# Out:
# No Control              7692
# Traffic Signal          6771
# Stop Sign               1272
# Pedestrian Crossover     189
# Traffic Controller       100
# NaN                       29
# Streetcar (Stop for)      16
# Yield Sign                13
# Traffic Gate               5
# School Guard               2
# PXO - No Ped               2
# Police Control             2
# Name: TRAFFCTL, dtype: int64

# %%
new_df.VISIBILITY.value_counts(dropna=False)
# Out:
# Clear                     13814
# Rain                       1711
# Snow                        333
# Other                        99
# Fog, Mist, Smoke, Dust       44
# Freezing Rain                43
# NaN                          22
# Drifting Snow                19
# Strong wind                   8
# Name: VISIBILITY, dtype: int64

# %%
new_df.LIGHT.value_counts(dropna=False)
# Out:
# Daylight                9255
# Dark                    3525
# Dark, artificial        2609
# Dusk                     221
# Dusk, artificial         166
# Daylight, artificial     124
# Dawn                     102
# Dawn, artificial          85
# Other                      6
# Name: LIGHT, dtype: int64

# %%
new_df.RDSFCOND.value_counts(dropna=False)
# Out:
# Dry                     12820
# Wet                      2718
# Loose Snow                162
# Other                     147
# Slush                      96
# Ice                        73
# Packed Snow                42
# Unknown                    27
# Loose Sand or Gravel        7
# Spilled liquid              1
# Name: RDSFCOND, dtype: int64

# %%
new_df.INVTYPE.value_counts(dropna=False)
# Out:
# Driver                  7263
# Pedestrian              2715
# Passenger               2426
# Vehicle Owner           1636
# Cyclist                  684
# Motorcycle Driver        551
# Truck Driver             297
# Other Property Owner     257
# Other                    157
# Motorcycle Passenger      30
# Moped Driver              27
# Driver - Not Hit          16
# Wheelchair                13
# NaN                       10
# In-Line Skater             5
# Cyclist Passenger          2
# Trailer Owner              2
# Witness                    1
# Pedestrian - Not Hit       1
# Name: INVTYPE, dtype: int64

# %%
new_df.INVAGE.value_counts(dropna=False)
# Out:
# unknown     2541
# 20 to 24    1484
# 25 to 29    1417
# 30 to 34    1174
# 50 to 54    1150
# 35 to 39    1136
# 40 to 44    1134
# 45 to 49    1104
# 55 to 59     937
# 60 to 64     743
# 15 to 19     738
# 65 to 69     586
# 70 to 74     463
# 75 to 79     390
# 80 to 84     292
# 10 to 14     214
# 85 to 89     191
# 5 to 9       175
# 0 to 4       156
# 90 to 94      54
# Over 95       14
# Name: INVAGE, dtype: int64

# %%
new_df.INJURY.value_counts(dropna=False)
# Out:
# None       6068
# Major      5375
# NaN        1609
# Minor      1264
# Minimal     996
# Fatal       781
# Name: INJURY, dtype: int64

# %%
new_df.VEHTYPE.value_counts(dropna=False)
# Out:
# Automobile, Station Wagon           6594
# Other                               4745
# NaN                                 2527
# Bicycle                              680
# Motorcycle                           551
# Municipal Transit Bus (TTC)          241
# Truck - Open                         173
# Pick Up Truck                        152
# Passenger Van                        105
# Delivery Van                          63
# Truck - Closed (Blazer, etc)          50
# Street Car                            39
# Truck - Dump                          32
# Truck-Tractor                         30
# Taxi                                  28
# Moped                                 22
# Truck (other)                         12
# Bus (Other) (Go Bus, Gray Coach)      11
# Intercity Bus                          9
# Truck - Tank                           7
# Tow Truck                              4
# School Bus                             4
# Police Vehicle                         4
# Construction Equipment                 4
# Fire Vehicle                           3
# Off Road - 2 Wheels                    1
# Truck - Car Carrier                    1
# Other Emergency Vehicle                1
# Name: VEHTYPE, dtype: int64

# %%
new_df.DRIVCOND.value_counts(dropna=False)
# Out:
# NaN                                   8061
# Normal                                5167
# Inattentive                           1318
# Unknown                                920
# Medical or Physical Disability         156
# Had Been Drinking                      146
# Ability Impaired, Alcohol Over .08     115
# Ability Impaired, Alcohol              106
# Fatigue                                 47
# Other                                   41
# Ability Impaired, Drugs                 16
# Name: DRIVCOND, dtype: int64

# %%
new_df_aug1 = new_df.dropna(thresh=4)
new_df_aug1.shape
# Out:
# (16093, 41)

# %%
new_df.duplicated().value_counts()
# Out:
# False    16093
# dtype: int64

# %%
sb.regplot(x='TIME', y='HOUR', data=new_df, scatter=True)
# Out:
# <AxesSubplot:xlabel='TIME', ylabel='HOUR'>

# %%
fig, ax = plt.subplots(figsize=(10, 5))

ax.plot(new_df['HOUR'], new_df['INVAGE'], color="blue", lw=1, ls='-', marker='o', markersize=6,  markerfacecolor="blue", markeredgewidth=1, markeredgecolor="blue", label="Age 0 to 9")

# Label for x-axis
plt.xlabel("Hour of the Day", fontsize=20, color="grey")

# Label for y-axis
plt.ylabel("# Accidents Involving Children", fontsize=20, color="grey")

ax.legend(loc=1)

ax.set_title("Time of Day for Accidents Involving People Under 20", fontsize=15, color="red")
# Out:
# Text(0.5, 1.0, 'Time of Day for Accidents Involving People Under 20')

# %%
sb.swarmplot(x="INJURY", y="TIME", data=new_df);
# Out:
# C:\Users\lotte\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 92.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\lotte\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 72.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\lotte\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 93.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\lotte\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 60.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\lotte\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 67.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
boxplt, ax = plt.subplots(figsize = (16,4))
ax =sb.boxplot(x="INJURY", y="TIME", hue="DRIVCOND", data=new_df)

plt.show()

# %%
boxplt, ax = plt.subplots(figsize = (16,4))
ax =sb.boxplot(x="INJURY", y="TIME", hue="VISIBILITY", data=new_df)

plt.show()

# %%
sb.violinplot(x="INJURY", y="HOUR", data=new_df,
               bw=.1, scale="count", scale_hue=False);

# %%
new_df['DATE'] =  pd.to_datetime(new_df['DATE'], infer_datetime_format=True)
new_df.head(13)
# Out:
# 9       64  Woodbine Corridor (64)       10            2.0          NaN
# 10      64  Woodbine Corridor (64)       11            2.0          NaN
# 11      64  Woodbine Corridor (64)       12            2.0          6.0
# 12      64  Woodbine Corridor (64)       13            0.0          NaN
#
# [13 rows x 41 columns]

# %% [markdown]
# ### Monthly Trend Analysis

# %%
df_months = new_df.set_index('DATE')
df_months.head(3)
# Out:
#              Index_  ACCNUM  YEAR  TIME  HOUR               District  WardNum  \
# DATE
# 2006-01-01  3389067  893184  2006   236     2  Toronto and East York     19.0
# 2006-01-01  3389068  893184  2006   236     2  Toronto and East York     19.0
# 2006-01-01  3389069  893184  2006   236     2  Toronto and East York     19.0
#
#             Division      ROAD_CLASS  ROAD_CLASS_Scale  ...           DRIVACT  \
# DATE                                                    ...
# 2006-01-01        54  Major Arterial               8.0  ...               NaN
# 2006-01-01        54  Major Arterial               8.0  ...               NaN
# 2006-01-01        54  Major Arterial               8.0  ...  Driving Properly
#
#             DRIVCOND DRIVCOND_Scale  SPEEDING ALCOHOL  Hood_ID  \
# DATE
# 2006-01-01       NaN            NaN       Yes     Yes       60
# 2006-01-01       NaN            NaN       Yes     Yes       60
# 2006-01-01    Normal            0.0       Yes     Yes       60
#
#                     Neighbourhood  ObjectId Vulnerability Vehicle mass
# DATE
# 2006-01-01  Woodbine-Lumsden (60)         1           2.0          NaN
# 2006-01-01  Woodbine-Lumsden (60)         2           2.0          NaN
# 2006-01-01  Woodbine-Lumsden (60)         3           2.0          6.0
#
# [3 rows x 40 columns]

# %%
df_months['Month'] = df_months.index.month
df_months.head(13)
# Out:
#              Index_  ACCNUM  YEAR  TIME  HOUR               District  WardNum  \
# DATE
# 2006-01-01  3389067  893184  2006   236     2  Toronto and East York     19.0
# 2006-01-01  3389068  893184  2006   236     2  Toronto and East York     19.0
# 2006-01-01  3389069  893184  2006   236     2  Toronto and East York     19.0
# 2006-01-01  3389070  893184  2006   236     2  Toronto and East York     19.0
# 2006-01-01  3389071  893184  2006   236     2  Toronto and East York     19.0
# 2006-01-01  3389072  893184  2006   236     2  Toronto and East York     19.0
# 2006-01-01  3389073  893184  2006   236     2  Toronto and East York     19.0
# 2006-01-01  3389074  893184  2006   236     2  Toronto and East York     19.0
# 2006-01-01  3433023  909646  2006   315     3  Toronto and East York     19.0
# 2006-01-01  3433024  909646  2006   315     3  Toronto and East York     19.0
# 2006-01-01  3433025  909646  2006   315     3  Toronto and East York     19.0
# 2006-01-01  3433026  909646  2006   315     3  Toronto and East York     19.0
# 2006-01-01  3433027  909646  2006   315     3  Toronto and East York     19.0
#
#             Division      ROAD_CLASS  ROAD_CLASS_Scale  ...  \
# DATE                                                    ...
# 2006-01-01        54  Major Arterial               8.0  ...
# 2006-01-01        54  Major Arterial               8.0  ...
# 2006-01-01        54  Major Arterial               8.0  ...
# 2006-01-01        54  Major Arterial               8.0  ...
# 2006-01-01        54  Major Arterial               8.0  ...
# 2006-01-01        54  Major Arterial               8.0  ...
# 2006-01-01        54  Major Arterial               8.0  ...
# 2006-01-01        54  Major Arterial               8.0  ...
# 2006-01-01        54  Major Arterial               8.0  ...
# 2006-01-01        54  Major Arterial               8.0  ...
# 2006-01-01        54  Major Arterial               8.0  ...
# 2006-01-01        54  Major Arterial               8.0  ...
# 2006-01-01        54  Major Arterial               8.0  ...
#
#                                       DRIVCOND  DRIVCOND_Scale SPEEDING  \
# DATE
# 2006-01-01                                 NaN             NaN      Yes
# 2006-01-01                                 NaN             NaN      Yes
# 2006-01-01                              Normal             0.0      Yes
# 2006-01-01                                 NaN             NaN      Yes
# 2006-01-01                                 NaN             NaN      Yes
# 2006-01-01                                 NaN             NaN      Yes
# 2006-01-01                                 NaN             NaN      Yes
# 2006-01-01  Ability Impaired, Alcohol Over .08             8.0      Yes
# 2006-01-01                                 NaN             NaN      NaN
# 2006-01-01                                 NaN             NaN      NaN
# 2006-01-01                                 NaN             NaN      NaN
# 2006-01-01                         Inattentive             5.0      NaN
# 2006-01-01                                 NaN             NaN      NaN
#
#             ALCOHOL Hood_ID           Neighbourhood ObjectId  Vulnerability  \
# DATE
# 11     12.335570  34.185185          7.336398        4.966493
# 12     12.499027  35.222039          7.408703        4.878613
#
#        VISIBILITY_Scale  ...  RDSFCOND_Scale  INVTYPE_Scale  INVAGE_Scale  \
# Month                    ...
# 1              1.788732  ...        2.295009       2.991189      9.560797
# 2              1.540183  ...        1.951496       2.964431      9.197287
# 3              1.336947  ...        1.547729       2.960325      9.143478
# 4              1.474870  ...        1.430556       2.876298      8.888325
# 5              1.308943  ...        1.232036       2.892070      8.762860
# 6              1.232529  ...        1.187113       3.158318      8.904100
# 7              1.171153  ...        1.126819       3.016586      8.723090
# 8              1.139805  ...        1.121398       3.053823      8.869534
# 9              1.316883  ...        1.260131       3.107862      9.088394
# 10             1.611979  ...        1.474443       3.201434      9.140625
# 11             1.601632  ...        1.533784       3.252039      9.685073
# 12             1.863636  ...        2.034599       3.194901      9.354808
#
#        INJURY_Scale  VEHTYPE_Scale  DRIVCOND_Scale    Hood_ID     ObjectId  \
# Month
# 1          2.612488       3.805291        1.167549  78.704225  7498.357394
# 2          2.576536       3.662275        1.457983  71.899390  7263.287602
# 3          2.563126       3.770563        1.199275  73.323715  8046.621280
# 4          2.587379       3.697626        1.174576  70.767301  7646.442042
# 5          2.577143       3.559896        1.167388  73.079295  7924.238620
# 6          2.547274       3.389205        1.102532  73.978973  7899.427953
# 7          2.576245       3.393114        1.301389  73.452726  7732.865424
# 8          2.511486       3.578331        1.007246  74.697192  7978.076313
# 9          2.609633       3.670924        1.288750  74.287013  8157.451948
# 10         2.561135       3.574864        1.224436  72.608724  8591.617188
# 11         2.583333       3.808969        1.176558  76.231111  8750.451852
# 12         2.585145       3.814852        1.147708  74.626645  8766.992599
#
#        Vulnerability  Vehicle mass
# Month
# 1           2.991189      3.805291
# 2           2.964431      3.662275
# 3           2.960325      3.770563
# 4           2.876298      3.697626
# 5           2.892070      3.559896
# 6           3.158318      3.389205
# 7           3.016586      3.393114
# 8           3.053823      3.578331
# 9           3.107862      3.670924
# 10          3.201434      3.574864
# 11          3.252039      3.808969
# 12          3.194901      3.814852
#
# [12 rows x 21 columns]

# %%
fig, ax = plt.subplots(figsize=(8, 4))

ax.plot(df_months['Month'], df_months['RDSFCOND_Wet'], color="aqua", lw=1, ls='-', marker='o', markersize=6,  markerfacecolor="white", markeredgewidth=1, markeredgecolor="red", label="Wet")
ax.plot(df_months['Month'], df_months['RDSFCOND_Dry'], color="red", lw=1, ls='-', label="Dry")
ax.plot(df_months['Month'], df_months['RDSFCOND_Spilled Liquid'], color="green", lw=1, ls='-', label="Spilled Liquid")
ax.plot(df_months['Month'], df_months['RDSFCOND_Loose Sand or Gravel'], color="black", lw=1, ls='-', label="Loose Sand or Gravel")



# Label for x-axis
plt.xlabel("Month", fontsize=20, color="grey")

# Label for y-axis
plt.ylabel("# People In Accidents", fontsize=20, color="grey")

ax.legend(loc=1)

ax.set_title("People in Accidents Based on Road Conditions", fontsize=20, color="red")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'RDSFCOND_Wet'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-92-bbe505f724cc> in <module>
#       1 fig, ax = plt.subplots(figsize=(8, 4))
#       2
# ----> 3 ax.plot(df_months['Month'], df_months['RDSFCOND_Wet'], color="aqua", lw=1, ls='-', marker='o', markersize=6,  markerfacecolor="white", markeredgewidth=1, markeredgecolor="red", label="Wet")
#       4 ax.plot(df_months['Month'], df_months['RDSFCOND_Dry'], color="red", lw=1, ls='-', label="Dry")
#       5 ax.plot(df_months['Month'], df_months['RDSFCOND_Spilled Liquid'], color="green", lw=1, ls='-', label="Spilled Liquid")
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'RDSFCOND_Wet'

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import numpy as np
import sklearn as sk
import sklearn.datasets as skd
import sklearn.ensemble as ske
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
mpl.rcParams['figure.dpi'] = mpl.rcParams['savefig.dpi'] = 300

# %%
# new_df.head().T

# %%
new_df.ROAD_CLASS_Scale.value_counts(dropna=False)
# Out:
# 8.0    11555
# 6.0     2462
# 4.0      900
# 5.0      727
# NaN      414
# 9.0       24
# 3.0       10
# 7.0        1
# Name: ROAD_CLASS_Scale, dtype: int64

# %%
new_df.LIGHT_Scale.value_counts(dropna=False)
# Out:
# 2.0    9255
# 6.0    3525
# 5.0    2609
# 4.0     323
# 3.0     251
# 1.0     124
# NaN       6
# Name: LIGHT_Scale, dtype: int64

# %%
new_df.INJURY_Scale.value_counts(dropna=False)
# Out:
# 1.0    6068
# 4.0    5375
# NaN    1609
# 3.0    1264
# 2.0     996
# 5.0     781
# Name: INJURY_Scale, dtype: int64

# %%
# Selecting the feature columns
feature_cols = ["ROAD_CLASS_Scale", "LIGHT_Scale"]

# %%
X = new_df[feature_cols] # Features
y = new_df.INJURY_Scale # Target variable

# %%
# Split the dataset into 70% training data and 30% of testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
# Train the model with the help of DecisionTreeClassifier class
clf = DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-117-19b28a06f7c9> in <module>
#       1 clf = DecisionTreeClassifier()
# ----> 2 clf = clf.fit(X_train, y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     154             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     155             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 156             X, y = self._validate_data(X, y,
#     157                                        validate_separately=(check_X_params,
#     158                                                             check_y_params))
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     427                 # :(
#     428                 check_X_params, check_y_params = validate_separately
# --> 429                 X = check_array(X, **check_X_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     642
#     643         if force_all_finite:
# --> 644             _assert_all_finite(array,
#     645                                allow_nan=force_all_finite == 'allow-nan')
#     646
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      94                 not allow_nan and not np.isfinite(X).all()):
#      95             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 96             raise ValueError(
#      97                     msg_err.format
#      98                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
# Next we make a prediction
y_pred = clf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-120-cb75fb6d8276> in <module>
#       1 # Next we make a prediction
# ----> 2 y_pred = clf.predict(X_test)
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in predict(self, X, check_input)
#     424             The predicted classes, or the predict values.
#     425         """
# --> 426         check_is_fitted(self)
#     427         X = self._validate_X_predict(X, check_input)
#     428         proba = self.tree_.predict(X)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1017
#    1018     if not attrs:
# -> 1019         raise NotFittedError(msg % {'name': type(estimator).__name__})
#    1020
#    1021
#
# NotFittedError: This DecisionTreeClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
# Get the accuracy score, confusion matrix and classification report
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
result = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(result)
result1 = classification_report(y_test, y_pred)
print("Classification Report:",)
print (result1)
result2 = accuracy_score(y_test,y_pred)
print("Accuracy:",result2)
